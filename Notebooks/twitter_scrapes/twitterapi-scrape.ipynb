# %% [markdown]
# # TwitterAPI
#
# This API will be able to return tweets within a given radius of a latitude/longitude

# %%
#!pip install TwitterAPI

# %%
from TwitterAPI import TwitterAPI
import json

import pandas as pd
import time

# %% [markdown]
# ### Waiting on credential confirmation

# %%
api = TwitterAPI(consumer_key='####################',
                 consumer_secret='####################',
                 access_token_key='####################',
                 access_token_secret='####################')

# %%
sandbox = 'fullarchive'
label = 'awharmonfulltest' # Specific to application and set in dev environment

# %%
list_tweets = []
#next=None

# %%
web_request_count = 3
web_request_count
# Out:
# 3

# %%
r = api.request('search/tweets', {'q':'-158.24,19.05,-154.89,21.71'})
for item in r:
        print(item)
# Out:
# ---------------------------------------------------------------------------
# TwitterRequestError                       Traceback (most recent call last)
# <ipython-input-22-4b04aff63f84> in <module>
#       1 r = api.request('search/tweets', {'location':'-158.24,19.05,-154.89,21.71'})
# ----> 2 for item in r:
#       3         print(item)
#
# /anaconda3/lib/python3.6/site-packages/TwitterAPI/TwitterAPI.py in __iter__(self)
#     217         :raises: TwitterConnectionError, TwitterRequestError
#     218         """
# --> 219         return self.get_iterator()
#     220
#     221     def get_quota(self):
#
# /anaconda3/lib/python3.6/site-packages/TwitterAPI/TwitterAPI.py in get_iterator(self)
#     204         """
#     205         if self.response.status_code != 200:
# --> 206             raise TwitterRequestError(self.response.status_code)
#     207
#     208         if self.stream:
#
# TwitterRequestError: Twitter request failed (400)

# %%
pd.DataFrame(r.json()['statuses'])
# Out:
#    contributors coordinates                      created_at  \
# 0          None        None  Tue Apr 23 13:34:43 +0000 2019
# 1          None        None  Mon Apr 22 23:05:07 +0000 2019
# 2          None        None  Mon Apr 22 19:31:30 +0000 2019
# 3          None        None  Mon Apr 22 18:00:14 +0000 2019
# 4          None        None  Mon Apr 22 08:01:57 +0000 2019
# 5          None        None  Mon Apr 22 06:44:13 +0000 2019
# 6          None        None  Mon Apr 22 05:52:41 +0000 2019
# 7          None        None  Sun Apr 21 17:48:26 +0000 2019
# 8          None        None  Sun Apr 21 17:19:03 +0000 2019
# 9          None        None  Sun Apr 21 13:30:10 +0000 2019
# 10         None        None  Sun Apr 21 13:00:05 +0000 2019
# 11         None        None  Sun Apr 21 08:31:48 +0000 2019
# 12         None        None  Sun Apr 21 08:24:45 +0000 2019
# 13         None        None  Sun Apr 21 08:19:27 +0000 2019
# 14         None        None  Sun Apr 21 08:19:10 +0000 2019
#
# ...

# %%
# returns a current stream of tweets
# required a kernal interrupt to halt

# r = api.request('statuses/filter', {'locations':'-158.24,19.05,-154.89,21.71'})
# for item in r:
#         print(item)
# Out:
# {'created_at': 'Mon Apr 22 21:14:15 +0000 2019', 'id': 1120435673746550784, 'id_str': '1120435673746550784', 'text': 'Weezy f baby please suck the balls', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 3251440891, 'id_str': '3251440891', 'name': '¿', 'screen_name': 'jta__93', 'location': 'Hilo, HI', 'url': None, 'description': 'trouble in paradise', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 259, 'friends_count': 2305, 'listed_count': 12, 'favourites_count': 11726, 'statuses_count': 4631, 'created_at': 'Sun Jun 21 07:48:59 +0000 2015', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'p
# ...

# %%
# Premium twitterapi filter
# res = api.request('tweets/search/%s/:%s' % (sandbox, label),
#                   {'query':'point_radius:[-155.5149 19.6242 50mi]', # Long/Lat for Hawaii (big island)
#                    'toDate':'201904010000', # start date = 04/01/2019
#                    'fromDate':'201904150000', # end date = 04/15/2019
#                    'next': next
# })


# Standard twitterapi filter
# while next is not None:
res = api.request('https://stream.twitter.com/1.1/statuses/filter.json',{
    #'query':'bounding_box:[-158.24,19.05,-154.89,21.71]' # Long/Lat for Hawaii
    #'toDate':'201904010000', # start date = 04/01/2019
    #'fromDate':'201904150000', # end date = 04/15/2019
    #'next': next
})

print('res.status_code: ', res.status_code)
#     next = res.json()['next']
#     print('next: ', next)
#     print('web_request_count: ', web_request_count)
#     web_request_count += 1

#     results = res.json()['results']

#     for tweet in results:

#         coordinates = tweet['coordinates']['coordinates']
#         tweet_date = tweet['created_at']
#         tweet_text = tweet['text']                              

#         if 'extended_tweet' in tweet.keys():
#             tweet_text = tweet['extended_tweet']['full_text']  

#         tweet_row = {'long_lat':coordinates,
#                     'date_utc':tweet_date,
#                     'full_text':tweet_text}

#         list_tweets.append(tweet_row) 

#     df = pd.DataFrame(list_tweets)

#     df.to_json('tweets_hawaii_2019_april_1-15.json', orient='records')
    
#     time.sleep(2) # wait i.e. only 30 requests per minute allowed
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-a9a5de6635c8> in <module>
#       7
#       8 # while next is not None:
# ----> 9 res = api.request('https://stream.twitter.com/1.1/statuses/filter.json',{
#      10     #'query':'bounding_box:[-158.24,19.05,-154.89,21.71]' # Long/Lat for Hawaii
#      11     #'toDate':'201904010000', # start date = 04/01/2019
#
# /anaconda3/lib/python3.6/site-packages/TwitterAPI/TwitterAPI.py in request(self, resource, params, files, method_override)
#     120         :raises: TwitterConnectionError
#     121         """
# --> 122         resource, endpoint = self._get_endpoint(resource)
#     123         if endpoint not in ENDPOINTS:
#     124             raise Exception('Endpoint "%s" unsupported' % endpoint)
#
# /anaconda3/lib/python3.6/site-packages/TwitterAPI/TwitterAPI.py in _get_endpoint(self, resource)
# ...

# %%
results = res.json()['results']
print(len(results))
print(len(list_tweets))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-253a174cc84b> in <module>
# ----> 1 results = res.json()['results']
#       2 print(len(results))
#       3 print(len(list_tweets))
#
# KeyError: 'results'
